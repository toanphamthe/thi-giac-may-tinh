# %%
# Cài đặt thư viện
# !pip install pillow

# %%
# Thêm thư viện
from PIL import Image
from imgtool import *

# %%
# Khai báo đưỡng dẫn chứa thư mục
dir = 'C:/Users/DevG/OneDrive/Documents/Thi Giac May Tinh/Image/01'

# %%
imgs = get_image_list(dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (474, 601)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x601>
# (325, 325)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=325x325>
# (325, 325)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=325x325>
# (432, 243)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=432x243>
# (474, 601)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x601>
# (474, 601)
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=474x601>
