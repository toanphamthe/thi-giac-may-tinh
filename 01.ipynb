# %%
# Cài đặt thư viện
# !pip install pillow

# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.8 MB 825.8 kB/s eta 0:00:47
#    ---------------------------------------- 0.2/38.8 MB 1.8 MB/s eta 0:00:22
#    ---------------------------------------- 0.5/38.8 MB 2.6 MB/s eta 0:00:15
#     --------------------------------------- 0.8/38.8 MB 3.7 MB/s eta 0:00:11
#    - -------------------------------------- 1.3/38.8 MB 5.0 MB/s eta 0:00:08
#    - -------------------------------------- 1.9/38.8 MB 6.1 MB/s eta 0:00:07
#    -- ------------------------------------- 2.4/38.8 MB 7.1 MB/s eta 0:00:06
#    --- ------------------------------------ 3.0/38.8 MB 7.5 MB/s eta 0:00:05
#    --- ------------------------------------ 3.5/38.8 MB 7.7 MB/s eta 0:00:05
#    ---- ----------------------------------- 4.1/38.8 MB 8.1 MB/s eta 0:00:05
# ...

# %%
# !pip install matplotlib

# %%
# !pip install scipy

# %%
# !pip install wordcloud

# %%
# Thêm thư viện
from PIL import Image

# %%
# Khai báo đưỡng dẫn chứa thư mục
dir = 'C:/Users/DevG/OneDrive/Documents/Thi Giac May Tinh/Image/01'

# %%
# Khai báo đường dẫn ảnh
image_path = dir + '/01.jpg'
print(image_path)
# Out:
# C:/Users/DevG/OneDrive/Documents/Thi Giac May Tinh/Image/01/01.jpg

# %%
# Sử dụng Image.open() để đọc ảnh
img01 = Image.open(image_path)

# %%
# Hiển thị ảnh
display(img01)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x601>

# %%
# In ra định dạng ảnh
print(img01.format)
# Out:
# JPEG

# %%
#Kích cỡ ảnh
print(img01.size)
# Out:
# (474, 601)

# %%
new_img01_path = dir + '/new_img01.jpg'
new_img01_png_path = dir + '/new_img01.png'
img01.save(new_img01_path)
img01.save(new_img01_png_path)

# %%
# Đóng tập tin
img01.close()
